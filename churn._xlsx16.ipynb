# %%
print('ldoa')
# Out:
# ldoa

# %%
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\vikas kumar\Downloads\Churn_Unclean_Project.xlsx")
df.head()
# Out:
#   Customer_ID     Customer_Name  Gender   Age        State       City  \
# 0       C1000  Abhishek Jaiswal  Female  35.0  Maharashtra       Pune
# 1       C1001       Rohit Kumar    Male   NaN        Delhi      Noida
# 2       C1002       Pooja Singh  Female  42.0           UP     Kanpur
# 3       C1003               NaN    Male  59.0    Karnataka  Bengaluru
# 4       C1004       Mohit Arora   male   26.0      Gujarat  Ahmedabad
#
#    Tenure_Months Subscription_Type  Monthly_Charges  Total_Charges  \
# 0           58.0             basic          1614.26       93273.08
# 1           36.0           Premium           429.60       15858.60
# 2           13.0             Basic           555.03        6869.39
# 3           55.0          Standard              NaN      101349.10
# 4            6.0           Premium           314.02        1926.12
#
#     Contract_Type Payment_Method Internet_Service Tech_Support Senior_Citizen  \
# ...

# %%
import os

for file in os.listdir(r"C:\Users\vikas kumar\Downloads"):
    if file.endswith(".xlsx"):
        print(file)
# Out:
# 14GRLPS3637D1ZL_4A_132024.xlsx
# 14GRLPS3637D1ZL_4A_142024.xlsx
# 14GRLPS3637D1ZL_4A_152024.xlsx
# 14GRLPS3637D1ZL_4A_162024 (1).xlsx
# 14GRLPS3637D1ZL_4A_162024.xlsx
# Category_Icons.xlsx
# Churn_Unclean_Project.xlsx
# ecommerce_sales_data.xlsx

# %%
import pandas as pd

df = pd.read_excel(r"C:\Users\vikas kumar\Downloads\Churn_Unclean_Project.xlsx")

df.head()
# Out:
#   Customer_ID     Customer_Name  Gender   Age        State       City  \
# 0       C1000  Abhishek Jaiswal  Female  35.0  Maharashtra       Pune
# 1       C1001       Rohit Kumar    Male   NaN        Delhi      Noida
# 2       C1002       Pooja Singh  Female  42.0           UP     Kanpur
# 3       C1003               NaN    Male  59.0    Karnataka  Bengaluru
# 4       C1004       Mohit Arora   male   26.0      Gujarat  Ahmedabad
#
#    Tenure_Months Subscription_Type  Monthly_Charges  Total_Charges  \
# 0           58.0             basic          1614.26       93273.08
# 1           36.0           Premium           429.60       15858.60
# 2           13.0             Basic           555.03        6869.39
# 3           55.0          Standard              NaN      101349.10
# 4            6.0           Premium           314.02        1926.12
#
#     Contract_Type Payment_Method Internet_Service Tech_Support Senior_Citizen  \
# ...

# %%
df = pd.read_excel('Churn_Unclean_Project.xlsx')

df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df = pd.read_excel('Churn_Unclean_Project.xlsx')
#       2
#       3 df.head()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\io\excel\_base.py:481, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     479 if not isinstance(io, ExcelFile):
#     480     should_close = True
# --> 481     io = ExcelFile(
#     482         io,
#     483         storage_options=storage_options,
#     484         engine=engine,
#     485         engine_kwargs=engine_kwargs,
#     486     )
#     487 elif engine and engine != io.engine:
# ...

# %%
pwd
# Out:
# 'C:\\Users\\Vikas Kumar'
